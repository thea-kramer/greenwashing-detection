# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Change the folder either to `instagram_data/` or to `twitter_data/`

# %%
folder  = 'twitter_data/' #twitter_data/ or instagram_data/

# %%
file = folder + 'posts_restructured.csv'
data = pd.read_csv(file)
data
# Out:
# /var/folders/pv/j2wxhdx50y5fbwqrc2yxqwf00000gn/T/ipykernel_73624/463771416.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file)
#         possibly_sensitive                                    tweets_original  \
# 0                    False  The Berlin State of Mind.\n\nEnjoy the true de...
# 1                    False  It's officially #SportscarTogether day! How ar...
# 2                    False  With #Germany experiencing usually high temper...
# 3                    False  The @FIAFormulaE comes to Zurich! Learn five t...
# 4                    False  RT @MercedesAMGF1: Friday, that’s a wrap... 🎬 ...
# ...                    ...                                                ...
# 306126               False  It's still not too late to meet the Brenntag B...
# 306127               False  RT @adidasrunning: There is a new dawn for run...
# 306128               False  Are your tires properly inflated? Now is a goo...
# 306129               False  In order to sustain our planet's finite resour...
# 306130               False  This year's #Indy500 pole sitter @edcarpenter2...
#
#                     source lang                created_at  \
# 0            erased6981162   en  2018-06-09T16:00:13.000Z
# 1       Twitter Web Client   en  2018-06-09T15:56:29.000Z
# 2                Percolate   en  2018-06-09T13:22:03.000Z
# 3            erased6981162   en  2018-06-09T13:04:15.000Z
# 4       Twitter Web Client   en  2018-06-09T08:28:41.000Z
# ...                    ...  ...                       ...
# 306126  Twitter Web Client   en  2018-05-23T07:30:16.000Z
# 306127         Twitter Ads   en  2018-05-22T22:20:56.000Z
# 306128             Emplifi   en  2018-05-22T19:30:38.000Z
# 306129         Twitter Ads   en  2018-05-22T18:47:00.000Z
# 306130             Emplifi   en  2018-05-22T17:32:53.000Z
#
#                          id           author       Branche          Branche-6  \
# 0       1005479690621026306     MercedesBenz     automobil          Automobil
# 1       1005478751809961986          Porsche     automobil          Automobil
# 2       1005439886764044290         MunichRe  versicherung  Finance/Insurance
# 3       1005435405473406976     MercedesBenz     automobil          Automobil
# 4       1005366057174032385     MercedesBenz     automobil          Automobil
# ...                     ...              ...           ...                ...
# 306126   999190762117107712         Brenntag        chemie            Technik
# 306127   999052517123108864           adidas          mode             Textil
# 306128   999009662685986816  continentaltire    automobil           Automobil
# 306129   998998679565451265         covestro        chemie            Technik
# 306130   998980027197800449  continentaltire    automobil           Automobil
#
#         Sektor  ...                                               urls  \
# 0          2.0  ...  [{'start': 72, 'end': 95, 'url': 'https://t.co...
# 1          2.0  ...  [{'start': 81, 'end': 104, 'url': 'https://t.c...
# 2          3.0  ...  [{'start': 249, 'end': 272, 'url': 'https://t....
# 3          2.0  ...  [{'start': 244, 'end': 267, 'url': 'https://t....
# 4          2.0  ...                                                 {}
# ...        ...  ...                                                ...
# 306126     2.0  ...  [{'start': 172, 'end': 195, 'url': 'https://t....
# 306127     2.0  ...                                                 {}
# 306128     2.0  ...  [{'start': 87, 'end': 110, 'url': 'https://t.c...
# 306129     2.0  ...  [{'start': 235, 'end': 258, 'url': 'https://t....
# 306130     2.0  ...  [{'start': 203, 'end': 226, 'url': 'https://t....
#
#         cashtags                                       entity_types  \
# 0            NaN  ['Organization', 'Other', 'Person', 'Organizat...
# 1            NaN                                 ['Other', 'Other']
# 2            NaN              ['Place', 'Other', 'Person', 'Other']
# 3            NaN  ['Place', 'Other', 'Other', 'Other', 'Other', ...
# 4            NaN                      ['Person', 'Person', 'Other']
# ...          ...                                                ...
# 306126       NaN  ['Other', 'Other', 'Place', 'Place', 'Other', ...
# 306127       NaN                                          ['Other']
# 306128       NaN                                          ['Other']
# 306129       NaN                                          ['Other']
# 306130       NaN                                          ['Other']
#
#                                              entity_names  \
# 0       ['Berlin State', 'Mind', 'Constantin Schiller'...
# 1                 ['SportscarTogether', 'Porsche70Years']
# 2       ['Germany', 'ExtremeWeather', 'Eberhard Faust'...
# 3       ['Zurich', 'Mercedes EQ', 'Allianz E-\n Villag...
# 4                     ['Valtteri', 'Lewis', 'CanadianGP']
# ...                                                   ...
# 306126  ['Brenntag Brazil Cosmetics Team', 'FCE Cosmet...
# 306127                                     ['SOLARBOOST']
# 306128                         ['NationalTireSafetyWeek']
# 306129                                    ['UTECHEurope']
# 306130                                        ['Indy500']
#
#                         mentioned_usernames  \
# 0                                        []
# 1                                        []
# 2                                        []
# 3                           ['FIAFormulaE']
# 4                         ['MercedesAMGF1']
# ...                                     ...
# 306126                                   []
# 306127                    ['adidasrunning']
# 306128                                   []
# 306129                                   []
# 306130  ['edcarpenter20', 'DWRshow', 'IMS']
#
#                                        mentioned_hashtags  \
# 0                         ['MBsocialcar', 'MercedesBenz']
# 1                 ['SportscarTogether', 'Porsche70Years']
# 2       ['Germany', 'ExtremeWeather', 'climatechange',...
# 3       ['SwitchToEQ', 'EQ', 'ABBFormulaE', 'ZurichEpr...
# 4                                          ['CanadianGP']
# ...                                                   ...
# 306126                ['fcecosmetique', 'BrenntagBrazil']
# 306127                                     ['SOLARBOOST']
# 306128                         ['NationalTireSafetyWeek']
# 306129  ['InnovationForSustainableGrowth', 'UTECHEurope']
# 306130                                        ['Indy500']
#
#                                          sourcetweet_text  year  \
# 0                                                     NaN  2018
# 1                                                     NaN  2018
# 2                                                     NaN  2018
# 3                                                     NaN  2018
# 4                                                     NaN  2018
# ...                                                   ...   ...
# 306126                                                NaN  2018
# 306127  There is a new dawn for running. See how #SOLA...  2018
# 306128                                                NaN  2018
# 306129                                                NaN  2018
# 306130                                                NaN  2018
#
#        more_information_provided  \
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                          False
# ...                          ...
# 306126                      True
# 306127                     False
# 306128                      True
# 306129                      True
# 306130                      True
#
#                                                 post_text
# 0       The Berlin State of Mind.\n\nEnjoy the true de...
# 1       It's officially #SportscarTogether day! How ar...
# 2       With #Germany experiencing usually high temper...
# 3       The @FIAFormulaE comes to Zurich! Learn five t...
# 4       RT @MercedesAMGF1: Friday, that’s a wrap... 🎬 ...
# ...                                                   ...
# 306126  It's still not too late to meet the Brenntag B...
# 306127  There is a new dawn for running. See how #SOLA...
# 306128  Are your tires properly inflated? Now is a goo...
# 306129  In order to sustain our planet's finite resour...
# 306130  This year's #Indy500 pole sitter @edcarpenter2...
#
# [306131 rows x 30 columns]

# %%
word_list_en = ['sustainab','climate','green','environment','ecofriendly','zero emission','zero-emission','clean energy','cleanenergy','ecolog','eco-friendly','biodegra','wind power','windpower','renewable','netzero','greenbuild','decarbon','recycl', 'pollut','zero waste','wind energy','co2 neutral','co2-neutral','solar', 'emissions','global warming','fairtrade','fairtrade']
word_list_de = ['nachhaltig', 'klima','umwelt','ökolog','erneuerbar','bio ','natur ','windkraft','energiespeicher','wärmepump']
word_list = word_list_en+word_list_de

word_list_en_recall = word_list_en + ['co2', 'reimaginecarbon','all-electric', 'emissionfree', 'emission free', 'planet','emobility','natur','waste']
word_list_de_recall = word_list_de + ['biologisch','grün']
word_list_high_recall = word_list_en_recall + word_list_de_recall

word_list_en_precision = [ elem for elem in word_list_en if not elem in ['green', 'climate', 'environment']]  
word_list_de_precision = [ elem for elem in word_list_de if not elem in ['klima','natur ']]  
word_list_high_precision = word_list_de_precision + word_list_en_precision

# %%
all = data.shape[0]
print('A list of words and in how many posts they appear (percentage):')
for word in word_list:
    print(word, round(data.loc[data['post_text'].str.contains(word, na=False, case=False,regex=True)].shape[0]*100.0/all,2), "%")
# Out:
# A list of words and in how many posts they appear (percentage):
# sustainab 2.56 %
# climate 1.07 %
# green 1.25 %
# environment 0.79 %
# ecofriendly 0.01 %
# zero emission 0.03 %
# zero-emission 0.03 %
# clean energy 0.05 %
# cleanenergy 0.1 %
# ecolog 0.05 %
# eco-friendly 0.03 %
# biodegra 0.02 %
# wind power 0.07 %
# windpower 0.18 %
# renewable 0.6 %
# netzero 0.04 %
# greenbuild 0.04 %
# decarbon 0.2 %
# recycl 0.2 %
# pollut 0.07 %
# zero waste 0.01 %
# wind energy 0.03 %
# co2 neutral 0.0 %
# co2-neutral 0.04 %
# solar 0.76 %
# emissions 0.56 %
# global warming 0.03 %
# fairtrade 0.0 %
# fairtrade 0.0 %
# nachhaltig 0.24 %
# klima 0.22 %
# umwelt 0.07 %
# ökolog 0.02 %
# erneuerbar 0.09 %
# bio  0.03 %
# natur  0.01 %
# windkraft 0.02 %
# energiespeicher 0.0 %
# wärmepump 0.0 %

# %% [markdown]
# The label whether a post is sustainable or not ('green') is calculated based on the words defined before

# %%
regex_query = ('|').join(word_list)
regex_query_recall = ('|').join(word_list_high_recall)
regex_query_precision = ('|').join(word_list_high_precision)
data['green'] = data['post_text'].str.contains(regex_query, na=False, case=False,regex=True)
data['green_recall'] = data['post_text'].str.contains(regex_query_recall, na=False, case=False,regex=True)
data['green_precision'] = data['post_text'].str.contains(regex_query_precision, na=False, case=False,regex=True)

# %% [markdown]
# All green posts are copied into an own dataframe called `green`

# %%
#optionally, replace data.green with data.green_recall for high recall or data.green_precision for high precision
green = data.loc[data.green]
pd.set_option('display.max_columns', None)
green
# Out:
#         possibly_sensitive                                    tweets_original  \
# 2                    False  With #Germany experiencing usually high temper...
# 23                   False  Every minute one garbage truck of plastic is d...
# 24                   False  RT @The_Linde_Group: 👋 Hello from Munich. Lind...
# 27                   False  Can you imagine a world with fewer cars, no tr...
# 39                   False  RT @TerliWetter: #Klimawandel #Klimakrise ist ...
# ...                    ...                                                ...
# 306117               False  At Allianz, #diversity plays an important role...
# 306121               False  RT @UNEnvironment: Humankind represents just 0...
# 306122               False  As a world-leading supplier of high-tech #poly...
# 306127               False  RT @adidasrunning: There is a new dawn for run...
# 306129               False  In order to sustain our planet's finite resour...
#
#                      source lang                created_at  \
# 2                 Percolate   en  2018-06-09T13:22:03.000Z
# 23      Sprinklr Publishing   en  2018-06-08T10:17:19.000Z
# 24       Twitter Web Client   en  2018-06-08T10:00:46.000Z
# 27                Percolate   en  2018-06-08T08:31:06.000Z
# 39       Twitter Web Client   de  2018-06-07T13:49:30.000Z
# ...                     ...  ...                       ...
# 306117   Twitter Web Client   en  2018-05-23T10:01:22.000Z
# 306121   Twitter Web Client   en  2018-05-23T08:11:05.000Z
# 306122          Twitter Ads   en  2018-05-23T07:58:00.000Z
# 306127          Twitter Ads   en  2018-05-22T22:20:56.000Z
# 306129          Twitter Ads   en  2018-05-22T18:47:00.000Z
#
#                          id    author       Branche          Branche-6  \
# 2       1005439886764044290  MunichRe  versicherung  Finance/Insurance
# 23      1005031008415223808    Henkel        chemie            Technik
# 24      1005026841655115777  Lindeplc        chemie            Technik
# 27      1005004276576354304  MunichRe  versicherung  Finance/Insurance
# 39      1004722015692050433  MunichRe  versicherung  Finance/Insurance
# ...                     ...       ...           ...                ...
# 306117   999228786485886976   Allianz  versicherung  Finance/Insurance
# 306121   999201035448090630   Allianz  versicherung  Finance/Insurance
# 306122   999197741057265664  covestro        chemie            Technik
# 306127   999052517123108864    adidas          mode             Textil
# 306129   998998679565451265  covestro        chemie            Technik
#
#         Sektor   B2B    B2C  likes  retweets  replies  quotes  \
# 2          3.0  True  False     13         4        1       0
# 23         2.0  True   True      9         3        1       0
# 24         2.0  True  False      0         5        0       0
# 27         3.0  True  False      4         4        0       0
# 39         3.0  True  False      0         4        0       0
# ...        ...   ...    ...    ...       ...      ...     ...
# 306117     3.0  True   True     11         3        0       0
# 306121     3.0  True   True      0       311        0       0
# 306122     2.0  True  False     12         5        0       0
# 306127     2.0  True   True      0       280        0       0
# 306129     2.0  True  False     19         4        0       2
#
#                      quote_ids              retweet_ids  \
# 2                           []                       []
# 23                          []                       []
# 24                          []  ['1004295430665068544']
# 27                          []                       []
# 39                          []  ['1004691958667907072']
# ...                        ...                      ...
# 306117  ['999227261860630528']                       []
# 306121                      []   ['999198280276938752']
# 306122                      []                       []
# 306127                      []   ['999038802822807552']
# 306129                      []                       []
#
#                         media_keys poll_ids  \
# 2                               {}      NaN
# 23      ['16_1005030984193118208']      NaN
# 24                              {}      NaN
# 27       ['3_1005004274672197632']      NaN
# 39                              {}      NaN
# ...                            ...      ...
# 306117                          {}       {}
# 306121                          {}       {}
# 306122   ['13_998939017759600640']       {}
# 306127                          {}       {}
# 306129   ['13_998939017172455429']       {}
#
#                                                      urls cashtags  \
# 2       [{'start': 249, 'end': 272, 'url': 'https://t....      NaN
# 23      [{'start': 277, 'end': 300, 'url': 'https://t....      NaN
# 24                                                     {}      NaN
# 27      [{'start': 249, 'end': 272, 'url': 'https://t....      NaN
# 39                                                     {}      NaN
# ...                                                   ...      ...
# 306117  [{'start': 179, 'end': 202, 'url': 'https://t....      NaN
# 306121  [{'start': 113, 'end': 136, 'url': 'https://t....      NaN
# 306122  [{'start': 256, 'end': 279, 'url': 'https://t....      NaN
# 306127                                                 {}      NaN
# 306129  [{'start': 235, 'end': 258, 'url': 'https://t....      NaN
#
#                                  entity_types  \
# 2       ['Place', 'Other', 'Person', 'Other']
# 23                                  ['Place']
# 24                         ['Place', 'Other']
# 27                                         []
# 39                                         []
# ...                                       ...
# 306117                              ['Place']
# 306121                                     []
# 306122                     ['Other', 'Other']
# 306127                              ['Other']
# 306129                              ['Other']
#
#                                              entity_names  \
# 2       ['Germany', 'ExtremeWeather', 'Eberhard Faust'...
# 23                                             ['Henkel']
# 24                                    ['Munich', 'Linde']
# 27                                                     []
# 39                                                     []
# ...                                                   ...
# 306117                                        ['Allianz']
# 306121                                                 []
# 306122                            ['SDGs', 'UTECHEurope']
# 306127                                     ['SOLARBOOST']
# 306129                                    ['UTECHEurope']
#
#                  mentioned_usernames  \
# 2                                 []
# 23                                []
# 24               ['the_linde_group']
# 27      ['Getaround', 'Maureeninno']
# 39       ['TerliWetter', 'MunichRe']
# ...                              ...
# 306117                            []
# 306121                            []
# 306122                  ['Utech_PU']
# 306127             ['adidasrunning']
# 306129                            []
#
#                                        mentioned_hashtags  \
# 2       ['Germany', 'ExtremeWeather', 'climatechange',...
# 23                                     ['WorldOceansDay']
# 24                                                     []
# 27                                            ['startup']
# 39                          ['Klimawandel', 'Klimakrise']
# ...                                                   ...
# 306117                         ['diversity', 'workplace']
# 306121                                                 []
# 306122  ['polymer', 'SDGs', 'InnovationForSustainableG...
# 306127                                     ['SOLARBOOST']
# 306129  ['InnovationForSustainableGrowth', 'UTECHEurope']
#
#                                          sourcetweet_text  year  \
# 2                                                     NaN  2018
# 23                                                    NaN  2018
# 24                                                    NaN  2018
# 27                                                    NaN  2018
# 39                                                    NaN  2018
# ...                                                   ...   ...
# 306117                                                NaN  2018
# 306121                                                NaN  2018
# 306122                                                NaN  2018
# 306127  There is a new dawn for running. See how #SOLA...  2018
# 306129                                                NaN  2018
#
#         more_information_provided  \
# 2                            True
# 23                           True
# 24                          False
# 27                           True
# 39                          False
# ...                           ...
# 306117                       True
# 306121                       True
# 306122                       True
# 306127                      False
# 306129                       True
#
#                                                 post_text  green  \
# 2       With #Germany experiencing usually high temper...   True
# 23      Every minute one garbage truck of plastic is d...   True
# 24      RT @The_Linde_Group: 👋 Hello from Munich. Lind...   True
# 27      Can you imagine a world with fewer cars, no tr...   True
# 39      RT @TerliWetter: #Klimawandel #Klimakrise ist ...   True
# ...                                                   ...    ...
# 306117  At Allianz, #diversity plays an important role...   True
# 306121  RT @UNEnvironment: Humankind represents just 0...   True
# 306122  As a world-leading supplier of high-tech #poly...   True
# 306127  There is a new dawn for running. See how #SOLA...   True
# 306129  In order to sustain our planet's finite resour...   True
#
#         green_recall  green_precision
# 2               True            False
# 23              True             True
# 24              True             True
# 27              True             True
# 39              True            False
# ...              ...              ...
# 306117          True            False
# 306121          True            False
# 306122          True             True
# 306127          True             True
# 306129          True             True
#
# [23911 rows x 33 columns]

# %%
data.to_csv(folder + 'posts_processed.csv', header=True, index=False, columns=list(data.axes[1]), lineterminator='\r\n')
green.to_csv(folder + 'green_posts_processed.csv', header=True, index=False, columns=list(green.axes[1]), lineterminator='\r\n')
